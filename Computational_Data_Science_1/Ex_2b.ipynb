# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
CovIndo= pd.read_csv('DATATOTALINDO.csv')
CovIndo.columns
# Out:
# Index(['Date', 'confirmed', 'recovered', 'death'], dtype='object')

# %%
print("Dimensi data  : {}".format(CovIndo.shape))
# Out:
# Dimensi data  : (79, 4)

# %%
CovIndo.plot.bar(x='Date', y='confirmed'); # too close

# %%
CovIndo.plot(kind='hist', alpha=.5, bins=20)

# %%
CovIndo.plot(kind='bar', alpha=0.9)  # belum bisa melebarkan ...bagaimaNA NIH

# %%
CovIndo.plot.bar() # HOW TO IMPROVE

# %%
#Cobacari di LANJUTKAN UNTUK EDIT di atas
#earthdatascience.org/courses/use-data-open-source-python/use-time-series-data-in-python/date-time-types-in-pandas-python/customize-dates-matplotlib-plots-python/
